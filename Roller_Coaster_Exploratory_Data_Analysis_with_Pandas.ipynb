# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)

# %%
df = pd.read_csv('/content/coaster_db.csv')

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
# Droping Columns
df.drop('Opening date', axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
# New DF add.copy
df = df[['coaster_name', 
    #'Length', 'Speed', 
    'Location', 'Status', 
    #'Opening date',
    #'Type', 
    'Manufacturer', 'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   Height restriction  831 non-null    object
#  5   Model               744 non-null    object
#  6   Height              965 non-null    object
#  7   year_introduced     1087 non-null   int64
#  8   latitude            812 non-null    float64
#  9   longitude           812 non-null    float64
#  10  Type_Main           1087 non-null   object
#  11  opening_date_clean  837 non-null    object
#  12  speed_mph           937 non-null    float64
#  13  height_ft           171 non-null    float64
#  14  Inversions_clean    1087 non-null   int64
# ...

# %%
df.describe()
# Out:
#        year_introduced    latitude   longitude   speed_mph   height_ft  \
# count      1087.000000  812.000000  812.000000  937.000000  171.000000
# mean       1994.986201   38.373484  -41.595373   48.617289  101.996491
# std          23.475248   15.516596   72.285227   16.678031   67.329092
# min        1884.000000  -48.261700 -123.035700    5.000000   13.100000
# 25%        1989.000000   35.031050  -84.552200   37.300000   51.800000
# 50%        2000.000000   40.289800  -76.653600   49.700000   91.200000
# 75%        2010.000000   44.799600    2.778100   58.000000  131.200000
# max        2022.000000   63.230900  153.426500  149.100000  377.300000
#
#        Inversions_clean  Gforce_clean
# count       1087.000000    362.000000
# mean           1.326587      3.824006
# std            2.030854      0.989998
# min            0.000000      0.800000
# 25%            0.000000      3.400000
# 50%            0.000000      4.000000
# 75%            2.000000      4.500000
# ...

# %%
df.shape
# Out:
# (1087, 16)

# %%
# opening_date_clean - object - Wrong because it is a date

df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# Height restriction     object
# Model                  object
# Height                 object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
# Alterado para datetime64
pd.to_datetime(df['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
# Rename our columns
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer',
#        'Height restriction', 'Model', 'Height', 'year_introduced', 'latitude',
#        'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns={'coaster_name':'Coaster_Name',
           'year_introduced':'Year_Introduced',
           'latitude':'Latitude',
           'longitude':'Longitude',
           'opening_date_clean':'Opening_Date',
           'speed_mph':'Speed_MPH',
           'height_ft':'Height_FT',
           'Inversions_clean':'Inversions',
           'Gforce_clean':'Gforce'})

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer Height restriction        Model  \
# 0  Removed  LaMarcus Adna Thompson                NaN  Lift Packed
# 1  Removed            Lina Beecher                NaN          NaN
# 2   Closed                     NaN                NaN          NaN
# 3  Removed          Edwin Prescott                NaN          NaN
# 4  Removed          Edwin Prescott                NaN          NaN
#
#          Height  Year_Introduced  Latitude  Longitude Type_Main Opening_Date  \
# ...

# %%
# ISNA - floating point - ISNULL same result
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Height restriction    256
# Model                 343
# Height                122
# Year_Introduced         0
# Latitude              275
# Longitude             275
# Type_Main               0
# Opening_Date          250
# Speed_MPH             150
# Height_FT             916
# Inversions              0
# Gforce                725
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Height restriction    256
# Model                 343
# Height                122
# Year_Introduced         0
# Latitude              275
# Longitude             275
# Type_Main               0
# Opening_Date          250
# Speed_MPH             150
# Height_FT             916
# Inversions              0
# Gforce                725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Height restriction  \
# 43                                  Traver Engineering                 NaN
# 60                                      Fred W. Pearce                 NaN
# 61                                                 NaN                 NaN
# 167  Arrow Development (California and Florida)Dyna...      40 in (102 cm)
# 237                                         Mack Rides  102 cm (3 ft 4 in)
#
#                            Model         Height  Year_Introduced  Latitude  \
# ...

# %%
# Checking a example duplicated
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#    Height restriction Model        Height  Year_Introduced  Latitude  \
# 39                NaN   NaN  96 ft (29 m)             1926   42.8617
# 43                NaN   NaN  96 ft (29 m)             1927   42.8617
#
#     Longitude Type_Main Opening_Date  Speed_MPH  Height_FT  Inversions  Gforce
# 39   -79.0598      Wood   1926-01-01       60.0        NaN           0     4.0
# 43   -79.0598      Wood   1926-01-01       60.0        NaN           0     4.0

# %%
# ~ -> Returns a non-duplicated array when used with duplicated
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])].reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 16)

# %%
df['Year_Introduced'].value_counts() # Which year was open most roller coast
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_Introduced, Length: 101, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts() \
  .head(10) \
  .plot(kind='bar', title='Top 10 Years Coasters Introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Speed_MPH'].plot(kind='hist', bins=20, title='Coaster Speed MPH')
ax.set_xlabel('Speed MPH')
# Out:
# Text(0.5, 0, 'Speed MPH')

# %%
ax = df['Speed_MPH'].plot(kind='kde', title='Coaster Speed MPH')
ax.set_xlabel('Speed MPH')
# Out:
# Text(0.5, 0, 'Speed MPH')

# %%
df.plot(kind='scatter', 
        x='Speed_MPH', 
        y='Height_FT',
        title='Coaster Speed vs Height')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
sns.scatterplot(x='Speed_MPH',
                y='Height_FT',
                hue='Year_Introduced',
                data=df)
# Out:
# <Axes: xlabel='Speed_MPH', ylabel='Height_FT'>

# %%
sns.pairplot(df, vars=['Year_Introduced','Speed_MPH',
                       'Height_FT', 'Inversions', 'Gforce'],
             hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year_Introduced','Speed_MPH', 'Height_FT', 'Inversions', 'Gforce']].dropna().corr()
df_corr
# Out:
#                  Year_Introduced  Speed_MPH  Height_FT  Inversions    Gforce
# Year_Introduced         1.000000   0.171978   0.135413   -0.209887  0.160247
# Speed_MPH               0.171978   1.000000   0.733999   -0.028705  0.607383
# Height_FT               0.135413   0.733999   1.000000   -0.079736  0.466482
# Inversions             -0.209887  -0.028705  -0.079736    1.000000  0.275991
# Gforce                  0.160247   0.607383   0.466482    0.275991  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
# What are the locations with the fastest roller coasters
df['Location'].value_counts()
# Out:
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: Location, Length: 280, dtype: int64

# %%
ax = df.query('Location != "Other"') \
      .groupby('Location')['Speed_MPH'] \
      .agg(['mean', 'count']) \
      .query('count >= 10') \
      .sort_values('mean') \
      .plot(kind='barh', figsize=(12, 5), title='Average Coaster Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
